# %% [markdown]
# ### Imports & Settings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
os.makedirs("../reports/visuals", exist_ok=True)


pd.set_option("display.max_columns", None)
sns.set(style="whitegrid", palette="viridis")

GOLD_DIR = "../data/gold"

# %% [markdown]
# ### Load Gold Tables

# %%
dim_book = pd.read_csv(f"{GOLD_DIR}/dim_book.csv")
dim_category = pd.read_csv(f"{GOLD_DIR}/dim_category.csv")
dim_rating = pd.read_csv(f"{GOLD_DIR}/dim_rating.csv")
dim_date = pd.read_csv(f"{GOLD_DIR}/dim_date.csv")
fact = pd.read_csv(f"{GOLD_DIR}/fact_book_metrics.csv")

dim_book.head(), dim_category.head(), dim_rating.head(), dim_date.head(), fact.head()
# Out:
# (   book_id                                   product_page_url  \
#  0        1  https://books.toscrape.com/catalogue/logan-kad...
#  1        2  https://books.toscrape.com/catalogue/the-torch...
#  2        3  https://books.toscrape.com/catalogue/the-mindf...
#  3        4  https://books.toscrape.com/catalogue/the-art-f...
#  4        5  https://books.toscrape.com/catalogue/on-a-midn...
#
#                                                 title  \
#  0                Logan Kade (Fallen Crest High #5.5)
#  1        The Torch Is Passed: A Harding Family Story
#  2  The Mindfulness and Acceptance Workbook for An...
#  3                                     The Art Forger
#  4                                On a Midnight Clear
#
#                                           description  \
#  0  People think that just because they know my na...
#  1  Andrea Harding is a recent college graduate lo...
#  2  Is anxiety and fear a problem for you? Have yo...
#  3  On March 18, 1990, thirteen works of art today...
#  4  It's Christmas Eve and private investigator Ad...
#
#                                             image_url
#  0  https://books.toscrape.com/media/cache/2b/44/2...
#  1  https://books.toscrape.com/media/cache/c7/26/c...
#  2  https://books.toscrape.com/media/cache/c9/eb/c...
#  3  https://books.toscrape.com/media/cache/f5/3b/f...
#  4  https://books.toscrape.com/media/cache/75/9d/7...  ,
#     category_id  category_name
#  0            1       Academic
#  1            2  Add A Comment
#  2            3  Adult Fiction
#  3            4         Travel
#  4            5        Mystery,
#     rating_id  rating_value rating_label
#  0          1             2          Two
#  1          2             1          One
#  2          3             4         Four
#  3          4             3        Three
#  4          5             5         Five,
#     date_id        date  year  month  day
#  0        1  2026-06-16  2026      6   16,
#     book_id  category_id  rating_id  date_id  price  availability
#  0        1            1          1        1  13.12             5
#  1        2            2          2        1  19.09            16
#  2        3            2          3        1  23.89            16
#  3        4            2          4        1  40.76            16
#  4        5            2          4        1  14.07            16)

# %% [markdown]
# ### Validate Row Counts

# %%
print("dim_book rows:", len(dim_book))
print("dim_category rows:", len(dim_category))
print("dim_rating rows:", len(dim_rating))
print("dim_date rows:", len(dim_date))
print("fact rows:", len(fact))
# Out:
# dim_book rows: 1000
# dim_category rows: 50
# dim_rating rows: 5
# dim_date rows: 1
# fact rows: 1000

# %% [markdown]
# ### Validate Keys & Uniqueness

# %%
print("Unique book_id in fact:", fact["book_id"].nunique())
print("Unique category_id in fact:", fact["category_id"].nunique())
print("Unique rating_id in fact:", fact["rating_id"].nunique())
print("Unique date_id in fact:", fact["date_id"].nunique())
# Out:
# Unique book_id in fact: 1000
# Unique category_id in fact: 50
# Unique rating_id in fact: 5
# Unique date_id in fact: 1

# %% [markdown]
# ### Join Fact + Dimensions (Analysis DataFrame)

# %%
df = (
    fact
    .merge(dim_book, on="book_id", how="left")
    .merge(dim_category, on="category_id", how="left")
    .merge(dim_rating, on="rating_id", how="left")
    .merge(dim_date, on="date_id", how="left")
)

df.head()

# %% [markdown]
# ### Basic Data Overview

# %%
df.info()
df.describe(include="all")

# %% [markdown]
# ### Price Distribution Plot

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["price"], bins=20, kde=True)
plt.title("Price Distribution of Books")
plt.xlabel("Price (£)")
plt.ylabel("Count")
plt.show()

plt.savefig("../reports/visuals/price_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Rating Distribution Plot

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="rating_value", data=df)
plt.title("Rating Distribution")
plt.xlabel("Rating (1–5)")
plt.ylabel("Count")
plt.show()

plt.savefig("../reports/visuals/rating_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Category Counts

# %%
plt.figure(figsize=(12,6))
df["category_name"].value_counts().sort_values().plot(kind="barh")
plt.title("Books per Category")
plt.xlabel("Count")
plt.ylabel("Category")
plt.show()

plt.savefig("../reports/visuals/books_per_category.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Top 10 Most Expensive Books

# %%
df.nlargest(10, "price")[["title", "category_name", "rating_value", "price"]]
